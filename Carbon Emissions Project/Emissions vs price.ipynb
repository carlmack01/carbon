# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
emissions = pd.read_csv('RGGI.csv')
emissions.head()
# Out:
#    Unnamed: 0  Year State  Allowances Sold  Auction Proceeds    Price  \
# 0           0  2008    CT        2745060.0         8852819.0  3.22500
# 1           1  2008    DE         755979.0         2555209.0  3.38000
# 2           2  2008    MA        8735068.0        28176794.0  3.22571
# 3           3  2008    MD        8735068.0        28176794.0  3.22571
# 4           4  2008    ME        1745012.0         5627664.0  3.22500
#
#    CO2\n(Metric Tons)  SO2\n(Metric Tons)  NOx\n(Metric Tons)
# 0            37802976               15488               29828
# 1            26387812              127920               45796
# 2            89052688              176124               75712
# 3           116621064              902092              165252
# 4            21254160              104920               42960

# %%
# Plot out rooms versus median house price
x_values = emissions['Price']
y_values = emissions['CO2\n(Metric Tons)']
plt.scatter(x_values,y_values)
plt.xlabel('Price')
plt.ylabel('CO2 In MEtric Tons')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Price')
plt.ylabel('CO2 Emissions')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02870559129559184

# %%
# Plot out rooms versus median house price
x_values2 = emissions['Year']
y_values2 = emissions['CO2\n(Metric Tons)']
plt.scatter(x_values2,y_values2)
plt.xlabel('Year')
plt.ylabel('CO2 In MEtric Tons')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values2, y_values2)
regress_values2 = x_values2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values2,y_values2)
plt.plot(x_values2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Year')
plt.ylabel('CO2 Emissions')
print(f"The r-squared is: {rvalue**2}")
plt.show()
print(line_eq)
# Out:
# The r-squared is: 0.02093980923206776
# y = -1969395.47x + 4009844383.34

# %%
x_values3 = emissions['Year']
y_values3 = emissions['Allowances Sold']
plt.scatter(x_values3,y_values3)
plt.xlabel('Year')
plt.ylabel('Allowances Sold')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values3, y_values3)
regress_values2 = x_values3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values3,y_values3)
plt.plot(x_values2,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Year')
plt.ylabel('Allowances Sold')
print(f"The r-squared is: {rvalue**2}")
plt.show()
print(line_eq)
# Out:
# The r-squared is: 0.018092237810143227
# y = -469056.73x + 952702971.04
